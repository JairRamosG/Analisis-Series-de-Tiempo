# %%
import os
import sys

sys.path.insert(0, "..")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Importar modulos src
from src.graficar import graficar_serie
from src.evaluar import evaluar_forecast
#from src.ARIMA_experimento import ARIMA_experimento

import torch
from torch.utils.data import DataLoader

# %% [markdown]
# ### Importación de la series de tiempo NASDAQ

# %%
ruta = '../data/raw_data/nasdaq.csv'
serie = pd.read_csv(ruta, names = ['Valores'])
serie.head()
# Out:
#    Valores
# 0   459.33
# 1   460.90
# 2   459.39
# 3   458.22
# 4   458.71

# %%
print(serie.shape)
serie.info()
# Out:
# (1500, 1)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Valores  1500 non-null   float64
# dtypes: float64(1)
# memory usage: 11.8 KB

# %%
serie.describe()
# Out:
#            Valores
# count  1500.000000
# mean    643.918093
# std     176.140441
# min     325.440000
# 25%     496.162500
# 50%     658.285000
# 75%     760.222500
# max    1069.800000

# %% [markdown]
# ### Graficar la serie original

# %%
graficar_serie(serie, variable='Valores', color='red', titulo='Serie de Tiempo NASDAQ Original')

# %% [markdown]
# ### Limpieza de la serie

# %%
### Valores nulos
serie['Valores'].isna().sum()

# No hay que imputar, entonces por esta vez la voy a trabajar así y antes de meterla en el modelo la transformo
# Out:
# 0
