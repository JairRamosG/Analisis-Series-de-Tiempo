# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('RUL_FD001.txt', header = None)
df.head()
# Out:
#      0
# 0  112
# 1   98
# 2   69
# 3   82
# 4   91

# %%
df.plot()
# Out:
# <Axes: >
